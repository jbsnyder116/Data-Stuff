# %% [markdown]
# <a href="https://colab.research.google.com/github/jbsnyder116/Data-Stuff/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('TitanicRB.csv')

# %%
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  Pclass Embarked  Survived
# ...

# %%
pd.crosstab(index = df['Sex'], columns=df['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %% [markdown]
# If sex = female, then we predict survived = 1

# %% [markdown]
# If sex = male, then we predict survived = 0

# %% [markdown]
# The error rate 190/891 = .213

# %%
pd.crosstab(index=df['Pclass'], columns=df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %% [markdown]
# If PClass = 1, then predict that they will survive

# %% [markdown]
# If PClass = 2, then predict that they will die.

# %% [markdown]
# If PClass = 3, then predict that they will die.

# %% [markdown]
# The error rate =  286/891 = .320

# %%
pd.crosstab(index=df['Embarked'], columns=df['Survived'])
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217

# %% [markdown]
# If Embarked = C, then predict that they will survive

# %% [markdown]
# If Embarked = Q, then predict that they will survive.

# %% [markdown]
# If Embarked = S, then predict that they will die.

# %% [markdown]
# The error rate is 322/891 = .36

# %% [markdown]
# The final Rule Set:

# %% [markdown]
# If sex = female, then we predict survived = 1.
# If sex = male, then we predict survived = 0.  This has the smallest/lowest error rate of .213.
