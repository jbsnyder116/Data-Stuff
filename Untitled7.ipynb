# %% [markdown]
# <a href="https://colab.research.google.com/github/jbsnyder116/Data-Stuff/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("bottles.csv")

# %%
df
# Out:
#      Unnamed: 0  Depthm  T_degC   Salnty  O2ml_L    STheta
# 0        282769       0  16.810  33.6600   5.430  24.53100
# 1        657442      91  13.700  33.3240   5.740  24.95700
# 2        157944       9  12.400  33.5900   6.350  25.41900
# 3         45210     125   9.240  32.8850   5.290  25.42700
# 4        474774      30  16.330  35.1900     NaN  25.82000
# ..          ...     ...     ...      ...     ...       ...
# 995      234834     381   7.840  34.4200     NaN  26.84800
# 996      503295      41  13.760  33.4160   6.340  25.01500
# 997      165309     250   9.590  34.4840     NaN  26.62300
# 998      544600     250   8.770  34.1990     NaN  26.53200
# 999      874919     250   7.593  33.9939   2.351  26.55027
#
# [1000 rows x 6 columns]

# %%
df = df.dropna()

# %%
sum(df['STheta'].isnull())
# Out:
# 0

# %%
df.plot.scatter('Depthm', 'STheta')
# Out:
# <Axes: xlabel='Depthm', ylabel='STheta'>

# %%
from sklearn.linear_model import LinearRegression
df.dropna()
model = LinearRegression()
x_train = df['Depthm'].values.reshape(-1, 1)
y_train = df['STheta'].values
model.fit(x_train, y_train)
y_pred = model.predict(df['Depthm'].values.reshape(-1, 1))

df.plot.scatter('Depthm', 'STheta')
plt.plot(df['Depthm'].values, y_pred, color='red', linewidth=3)

plt.xlabel('Depth (meters)')
plt.ylabel('Potential Density (kg/m^3)')
plt.title('Potential Density vs Depth')

plt.show()
